# %%
import torch
import torch.nn as nn
import torch.optim as optim

# from torchtext.datasets import TranslationDataset, Multi30k
# from torchtext.data import Field, BucketIterator

import spacy
import numpy as np

import random
import math
import time

# %%
import os
import shutil
import zipfile

import pandas as pd
import tensorflow as tf
import urllib3
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# %%
try:
    df = pd.read_csv('chatbotdata.csv')
except:
    import xlwings as xw
    df = xw.Book('chatbotdata.csv')
    df = df.sheets(1).used_range.options(pd.DataFrame, index = False).value

# %%
try:
    df1 = pd.read_csv('dataset_original.csv')
except:
    import xlwings as xw
    df1 = xw.Book('dataset_original.csv')
    df1 = df.sheets(1).used_range.options(pd.DataFrame, index = False).value

# %%
df
# Out:
#                              Q                         A  label
# 0                       12시 땡!                하루가 또 가네요.    0.0
# 1                  1지망 학교 떨어졌어                 위로해 드립니다.    0.0
# 2                 3박4일 놀러가고 싶다               여행은 언제나 좋죠.    0.0
# 3              3박4일 정도 놀러가고 싶다               여행은 언제나 좋죠.    0.0
# 4                      PPL 심하네                눈살이 찌푸려지죠.    0.0
# ...                        ...                       ...    ...
# 11818           훔쳐보는 것도 눈치 보임.        티가 나니까 눈치가 보이는 거죠!    2.0
# 11819           훔쳐보는 것도 눈치 보임.             훔쳐보는 거 티나나봐요.    2.0
# 11820              흑기사 해주는 짝남.                    설렜겠어요.    2.0
# 11821  힘든 연애 좋은 연애라는게 무슨 차이일까?  잘 헤어질 수 있는 사이 여부인 거 같아요.    2.0
# 11822               힘들어서 결혼할까봐        도피성 결혼은 하지 않길 바라요.    2.0
#
# [11823 rows x 3 columns]

# %%
df.drop('label', axis=1, inplace=True)

# %%
df
# Out:
#                              Q                         A
# 0                       12시 땡!                하루가 또 가네요.
# 1                  1지망 학교 떨어졌어                 위로해 드립니다.
# 2                 3박4일 놀러가고 싶다               여행은 언제나 좋죠.
# 3              3박4일 정도 놀러가고 싶다               여행은 언제나 좋죠.
# 4                      PPL 심하네                눈살이 찌푸려지죠.
# ...                        ...                       ...
# 11818           훔쳐보는 것도 눈치 보임.        티가 나니까 눈치가 보이는 거죠!
# 11819           훔쳐보는 것도 눈치 보임.             훔쳐보는 거 티나나봐요.
# 11820              흑기사 해주는 짝남.                    설렜겠어요.
# 11821  힘든 연애 좋은 연애라는게 무슨 차이일까?  잘 헤어질 수 있는 사이 여부인 거 같아요.
# 11822               힘들어서 결혼할까봐        도피성 결혼은 하지 않길 바라요.
#
# [11823 rows x 2 columns]

# %%
df1
# Out:
#              구분                                               유저  \
# 0     감정/감정조절이상  제 감정이 이상해진 것 같아요. 남편만 보면 화가 치밀어 오르고 감정 조절이 안되요.
# 1     감정/감정조절이상                         더 이상 내 감정을 내가 컨트롤 못 하겠어.
# 2     감정/감정조절이상                      하루종일 오르락내리락 롤러코스터 타는 기분이에요.
# 3     감정/감정조절이상                                꼭 롤러코스터 타는 것 같아요.
# 4     감정/감정조절이상                       롤러코스터 타는 것처럼 기분이 왔다 갔다 해요.
# ...         ...                                              ...
# 5226  현재상태/증상지속             한숨 자고 일어나면 괜찮으려나? 해서 자고 일어났는데도 똑같아요.
# 5227  현재상태/증상지속                            자고 나면 괜찮을 줄 알았는데 비슷해…
# 5228  현재상태/증상지속                                 지금도 상태가 계속 안 좋아.
# 5229  현재상태/증상지속                       이게 제 마음과 상관없이 증상이 계속 나타나요.
# 5230  현재상태/증상지속                    나이 들면 고쳐질 줄 알았는데…아직까지 계속 그래요.
#
#                                            챗봇  Unnamed: 3
# 0             감정이 조절이 안 될 때만큼 힘들 때는 없는 거 같아요.         NaN
# 1                      저도 그 기분 이해해요. 많이 힘드시죠?         NaN
# ...

# %%
df1.drop(['구분','Unnamed: 3'], axis=1, inplace=True)

# %%
df1.dropna(axis=0, inplace=True)

# %%
df1.columns = ['Q', 'A']

# %%
df1
# Out:
#                                                       Q  \
# 0       제 감정이 이상해진 것 같아요. 남편만 보면 화가 치밀어 오르고 감정 조절이 안되요.
# 1                              더 이상 내 감정을 내가 컨트롤 못 하겠어.
# 2                           하루종일 오르락내리락 롤러코스터 타는 기분이에요.
# 15    평소 다른 일을 할 때도 비슷해요. 생각한대로 안되면 화가 나고…그런 상황이 지속되...
# 16                                예전보다 화내는 게 과격해진 거 같아.
# ...                                                 ...
# 5196  그 사람이 응급실 의사한테 뭐라고 속닥거리니까, 저보고 갑자기 응급처치 끝났다고, ...
# 5197                   파편이 튀어서 그 때 저도 응급실 가서 치료 받기도 했고…
# 5213                     지금 상태가 너무 안 좋아서 학교 안 나가고 있어요.
# 5214                                   진짜 심해진 거 같긴 해요.
# 5215                                 그런데 증상이 나빠진 거 같아.
#
#                                                A
# 0                감정이 조절이 안 될 때만큼 힘들 때는 없는 거 같아요.
# 1                         저도 그 기분 이해해요. 많이 힘드시죠?
# 2        그럴 때는 밥은 잘 먹었는지, 잠은 잘 잤는지 체크해보는 것도 좋아요.
# 15    화가 폭발할 것 같을 때는 그 자리를 피하는 것도 좋은 방법이라고 생각해요.
# ...

# %%
result = pd.concat([df,df1], ignore_index=True)
pd.DataFrame(result)
# Out:
#                                                        Q  \
# 0                                                 12시 땡!
# 1                                            1지망 학교 떨어졌어
# 2                                           3박4일 놀러가고 싶다
# 3                                        3박4일 정도 놀러가고 싶다
# 4                                                PPL 심하네
# ...                                                  ...
# 12852  그 사람이 응급실 의사한테 뭐라고 속닥거리니까, 저보고 갑자기 응급처치 끝났다고, ...
# 12853                   파편이 튀어서 그 때 저도 응급실 가서 치료 받기도 했고…
# 12854                     지금 상태가 너무 안 좋아서 학교 안 나가고 있어요.
# 12855                                   진짜 심해진 거 같긴 해요.
# 12856                                 그런데 증상이 나빠진 거 같아.
#
#                                              A
# 0                                   하루가 또 가네요.
# 1                                    위로해 드립니다.
# 2                                  여행은 언제나 좋죠.
# 3                                  여행은 언제나 좋죠.
# ...

# %%
result.to_csv("dataset.csv")

# %%
import streamlit as st
from streamlit_chat import message
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import json
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13784\1784288155.py in <module>
# ----> 1 import streamlit as st
#       2 from streamlit_chat import message
#       3 import pandas as pd
#       4 from sentence_transformers import SentenceTransformer
#       5 from sklearn.metrics.pairwise import cosine_similarity
#
# c:\Python\3_7_9_x64\lib\site-packages\streamlit\__init__.py in <module>
#      53 __version__ = _STREAMLIT_VERSION_STRING
#      54
# ---> 55 from streamlit.delta_generator import DeltaGenerator as _DeltaGenerator
#      56 from streamlit.proto.RootContainer_pb2 import RootContainer as _RootContainer
#      57 from streamlit.runtime.caching import (
#
# c:\Python\3_7_9_x64\lib\site-packages\streamlit\delta_generator.py in <module>
#      36 from typing_extensions import Final, Literal
#      37
# ...

# %%
model = SentenceTransformer('jhgan/ko-sroberta-multitask')
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# c:\Python\3_7_9_x64\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#
# c:\Python\3_7_9_x64\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#
# c:\Python\3_7_9_x64\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1041         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042             conn.connect()
# ...
